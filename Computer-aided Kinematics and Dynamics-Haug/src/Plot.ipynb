# %%
using Plots 

anim = @animate for i in 1:50
    scatter(cumsum(randn(i)), ms=i, lab="", alpha = 1 - i/50, 
        xlim=(0,50), ylim=(-5, 7))
end

gif(anim, "anim.gif", fps = 15)
# Out:
# ┌ Info: Saved animation to c:\Users\17739\Git\Kinematics-Dynamics\Computer-aided Kinematics and Dynamics-Haug\src\anim.gif
# └ @ Plots C:\Users\17739\.julia\packages\Plots\3BCH5\src\animation.jl:156
# Plots.AnimatedGif("c:\\Users\\17739\\Git\\Kinematics-Dynamics\\Computer-aided Kinematics and Dynamics-Haug\\src\\anim.gif")
